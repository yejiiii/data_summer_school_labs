# %%
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import  linear_model
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %%
import tensorflow as tf

boston = load_boston()
x_data = boston.data
y_data = boston.target

# %%
W = tf.Variable(tf.random_uniform([1,13], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

X = np.float32(x_data)
Y = np.float32(y_data)

t_x_data = np.transpose(X)

hypothesis = tf.matmul(W, t_x_data) + b
cost = tf.reduce_mean(tf.square(hypothesis - y_data))

a = tf.Variable(0.000001)
optimizer = tf.train.GradientDescentOptimizer(a)
train = optimizer.minimize(cost)

init = tf.initialize_all_variables()


sess = tf.Session()
sess.run(init)

for step in range(50000):
    sess.run(train)
    if step % 2500 == 0:
        print (step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 25695.7 [[ 0.0615605   0.75851732  0.70875597  0.81504631  0.75866604  0.45675033
#   -0.4190664  -0.37617627  0.44318429  0.63455188  0.27582437 -0.46425718
#    0.97065997]] [ 0.01564384]
# 2500 130.309 [[-0.0339914   0.26055312  0.66372395  0.81747055  0.75955909  0.49166775
#   -0.08107534 -0.39679971  0.41157535 -0.05024434  0.28301784  0.04820609
#    0.75882411]] [ 0.01758129]
# 5000 107.798 [[-0.08842948  0.21310753  0.59247833  0.81917691  0.75982118  0.52645189
#   -0.06926092 -0.39472952  0.41094363 -0.04364281  0.28403229  0.04927272
#    0.54907471]] [ 0.01947258]
# 7500 91.9115 [[-0.12677544  0.19870479  0.52796406  0.82078916  0.76020312  0.56033182
#   -0.04925584 -0.39102978  0.40806848 -0.03863796  0.28814071  0.04809017
#    0.36974651]] [ 0.02152816]
# 10000 80.1644 [[-0.15314609  0.1904725   0.47055951  0.82227927  0.76065016  0.59272671
#   -0.02898673 -0.38693291  0.40402204 -0.03470844  0.29425672  0.04662504
#    0.21581239]] [ 0.02364384]
# 12500 71.3854 [[-0.17059846  0.18397555  0.41954675  0.82369226  0.76111668  0.62367624
#   -0.01102198 -0.38265809  0.39905477 -0.03145128  0.30182105  0.04525088
#    0.08330752]] [ 0.02578918]
# 15000 64.7677 [[-0.18143481  0.17827441  0.37420893  0.82503337  0.76171273  0.65331852
#    0.00444627 -0.37831613  0.39326853 -0.02869911  0.3104634   0.0440113
#   -0.03092422]] [ 0.02795077]
# 17500 59.7363 [[-0.18740173  0.17312591  0.33389509  0.8263638   0.76230878  0.68179017
#    0.01767669 -0.37392566  0.38675669 -0.02635174  0.3198882   0.04289037
#   -0.12951703]] [ 0.03012003]
# 20000 55.8779 [[-0.18982473  0.16843975  0.29802388  0.82755589  0.76290482  0.70920825
#    0.02897213 -0.36960432  0.37962097 -0.02433577  0.32985461  0.04186749
