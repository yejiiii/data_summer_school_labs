# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def difference_quotient(f, x, h):
    return (f(x + h) - f(x)) / h

# %%
from numpy import arange

x_vector = [i for i in arange(-4, 4,0.1)]

def custom_function(x):
    return x**4+x**3-8*x**2-12*x


y_vector = [custom_function(x) for x in x_vector]

plt.plot(x_vector, y_vector)
plt.show()

# %%
graient_vector = [difference_quotient(custom_function, x,h=0.00001) for x in x_vector]

plt.plot(x_vector, graient_vector)
plt.show()

# %%
from numpy import arange

graph_x = [x for x in arange(-4, 4, 0.1)]
graph_y = [ x**4+x**3-8*x**2-12*x for x in graph_x ]


plt.plot(graph_x, graph_y)
plt.show()

# %%
import math 
print("using the gradient")
v = random.randint(-4,4)
print("Stringtiong point :", v)
tracking = []
tolerance = 0.0000001
while True:
    gradient = 4*v**3 + 3*v**2 - 16*v - 12
    tracking.append(v)
    next_v = gradient * -0.01 + v 
    if next_v < tolerance:     # stop if we're converging
        break
    v = next_v                              # continue if we're not

print("minimum v", v)
# Out:
# using the gradient
# Stringtiong point : -2
# minimum v -2

# %%
from numpy import arange

plt.plot (graph_x, graph_y)
plt.plot (tracking, [ i**4 + i**3 - 8*i**2 - 12*i for i in tracking], "ro")

plt.show()
