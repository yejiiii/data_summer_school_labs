# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# x^4 + x^3-8x^2-12x 
# 4x^3+3x^2-16x-12

x_vector = [i for i in np.arange(-5,5,0.1)]
print (x_vector)
def custom_function(x):
    return x**4+x**3-8*x**2-12*x


y_vector = [custom_function(x) for x in x_vector]

plt.plot(x_vector, y_vector)
plt.show()
# Out:
# [-5.0, -4.9000000000000004, -4.8000000000000007, -4.7000000000000011, -4.6000000000000014, -4.5000000000000018, -4.4000000000000021, -4.3000000000000025, -4.2000000000000028, -4.1000000000000032, -4.0000000000000036, -3.9000000000000039, -3.8000000000000043, -3.7000000000000046, -3.600000000000005, -3.5000000000000053, -3.4000000000000057, -3.300000000000006, -3.2000000000000064, -3.1000000000000068, -3.0000000000000071, -2.9000000000000075, -2.8000000000000078, -2.7000000000000082, -2.6000000000000085, -2.5000000000000089, -2.4000000000000092, -2.3000000000000096, -2.2000000000000099, -2.1000000000000103, -2.0000000000000107, -1.900000000000011, -1.8000000000000114, -1.7000000000000117, -1.6000000000000121, -1.5000000000000124, -1.4000000000000128, -1.3000000000000131, -1.2000000000000135, -1.1000000000000139, -1.0000000000000142, -0.90000000000001457, -0.80000000000001492, -0.70000000000001528, -0.60000000000001563, -0.50000000000001599, -0.40000000000001634, -0.3000000000000167, -0.20000000000001705, -0.10000000000001741, -1.7763568394002505e-14, 0.099999999999981881, 0.19999999999998153, 0.29999999999998117, 0.39999999999998082, 0.49999999999998046, 0.5999999999999801, 0.69999999999997975, 0.79999999999997939, 0.89999999999997904, 0.99999999999997868, 1.0999999999999783, 1.199999999999978, 1.2999999999999776, 1.3999999999999773, 1.4999999999999769, 1.5999999999999766, 1.6999999999999762, 1.7999999999999758, 1.8999999999999755, 1.9999999999999751, 2.0999999999999748, 2.1999999999999744, 2.2999999999999741, 2.3999999999999737, 2.4999999999999734, 2.599999999999973, 2.6999999999999726, 2.7999999999999723, 2.8999999999999719, 2.9999999999999716, 3.0999999999999712, 3.1999999999999709, 3.2999999999999705, 3.3999999999999702, 3.4999999999999698, 3.5999999999999694, 3.6999999999999691, 3.7999999999999687, 3.8999999999999684, 3.999999999999968, 4.0999999999999677, 4.1999999999999673, 4.299999999999967, 4.3999999999999666, 4.4999999999999662, 4.5999999999999659, 4.6999999999999655, 4.7999999999999652, 4.8999999999999648]

# %%
def difference_quotient(f, x, h):
    return (f(x + h) - f(x)) / h

# %%
graient_vector = [difference_quotient(custom_function, x,h=0.00001) for x in x_vector]

plt.plot(x_vector, graient_vector)
plt.show()

# %%
from numpy import arange

graph_x = [i for i in arange(-5, 5, 0.001)]
graph_y = [ i**4+i**3-8*i**2-12*i for i in graph_x]

plt.plot(graph_x, graph_y)
plt.show()

# %%
import math 
print("using the gradient")
v = random.randint(0,150)
print("Stringtiong point :", v)
tracking = []
tolerance = 0.0000001
while True:
    gradient = v * 2
    tracking.append(v)
    next_v = gradient * -0.001 + v 
    if next_v < tolerance:     # stop if we're converging
        break
    v = next_v                              # continue if we're not

print("minimum v", v)
# Out:
# using the gradient
# Stringtiong point : 114
# minimum v 1.0014353106958603e-07

# %%
from numpy import arange

plt.plot(graph_x, graph_y)
plt.plot(tracking, [i**4+i**3-8*i**2-12*i  for i in tracking], "ro")

plt.show()
