# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def difference_quotient(f, x, h):
    return (f(x + h) - f(x)) / h

# %%
from numpy import arange

x_vector = [i for i in arange(-3, 3, 0.0001)]

def custom_function(x):
    return x**4 + x**3 -8*(x**2) - 12*x

y_vector = [custom_function(x) for x in x_vector]

plt.plot(x_vector, y_vector)
plt.show()

# %%
graient_vector = [difference_quotient(custom_function, x,h=0.00001) for x in x_vector]

plt.plot(x_vector, graient_vector)
plt.show()

# %%
import math 

print("using the gradient")
v = random.uniform(-3,3)

print("Stringtiong point :", v)
tracking = []

for i in range(1000000):
    gradient = 4*(v**3) + 3*(v**2) - 16*v - 12
    tracking.append(v)
    next_v = gradient * -0.00001 + v 
    v = next_v                             

print("minimum v", v)
# Out:
# using the gradient
# Stringtiong point : -0.7079734986548525
# minimum v 1.9999999999997478

# %%
from numpy import arange

plt.plot(x_vector, y_vector)
plt.plot(tracking, [custom_function(i) for i in tracking], "ro")
plt.show()
