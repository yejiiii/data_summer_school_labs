# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
from numpy import arange

graph_x = [i for i in arange(-3,3, 0.1)]
graph_y = [(i**4)+(i**3) -8*(i**2) -12*i for i in graph_x]

plt.plot(graph_x, graph_y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-24-e89c74ba880d> in <module>()
#       1 from numpy import arange
#       2
# ----> 3 graph_x = [i for i in arange(-3,3, 0)]
#       4 graph_y = [(i**4)+(i**3) -8*(i**2) -12*i for i in graph_x]
#       5
#
# ZeroDivisionError: division by zero

# %%
import math 
print("using the gradient")
v = random.randint(-3,3)
print("Stringtiong point :", v)

count=0
tracking = []
while(True):
    gradient = 4*(v**3)+3*(v**2)-16*v-12
    tracking.append(v)
    if (count !=0 and tracking[count]==tracking[count-1]): break
    next_v = gradient * -0.001 + v;
    v = next_v 
    count=count+1
print("minimum v", v)
# Out:
# using the gradient
# Stringtiong point : 3
# minimum v 2.000000000000005

# %%
from numpy import arange

plt.plot(graph_x, graph_y)
plt.plot(tracking, [(i**4)+(i**3) -8*(i**2) -12*i for i in tracking], "ro")

plt.show()
